# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahraGoli717/deep-learning-and-open-cv/blob/main/Object_tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 46.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11m.pt")

# Perform object detection on video
results = model("/content/sample_data/slow_traffic_small.mp4",classes=2, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/914) /content/sample_data/slow_traffic_small.mp4: 384x640 6 cars, 904.6ms
# video 1/1 (frame 2/914) /content/sample_data/slow_traffic_small.mp4: 384x640 6 cars, 868.3ms
# video 1/1 (frame 3/914) /content/sample_data/slow_traffic_small.mp4: 384x640 6 cars, 863.5ms
# video 1/1 (frame 4/914) /content/sample_data/slow_traffic_small.mp4: 384x640 6 cars, 910.3ms
# ...

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4 color=blue>
# 		<div align=right>
# 			<font face="B zar" size=5>
# 			  <p></p>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4 color=blue>
# 		<div align=right>
# 			<font face="B zar" size=5>
# 			  <p></p>
